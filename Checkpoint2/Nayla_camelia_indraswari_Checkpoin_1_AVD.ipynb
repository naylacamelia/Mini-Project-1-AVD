# %% [markdown]
# # **CheckPoin 1**

# %% [markdown]
# ## **BUSINESS UNDERSTANDING**

# %% [markdown]
# ###**1.	Business Objective**

# %% [markdown]
# Tujuan Bisnis: Tujuan utama dari proyek ini adalah untuk menganalisis faktor-faktor yang memengaruhi terjadinya kecelakaan lalu lintas. Analisis ini bertujuan untuk memahami pola serta risiko yang terkait dengan kecelakaan lalu lintas. Dengan demikian, proyek ini bertujuan untuk memberikan wawasan berbasis data yang dapat digunakan oleh pemerintah dan pihak terkait dalam meningkatkan keselamatan pengguna jalan serta mendukung pengambilan keputusan strategis.

# %% [markdown]
# ### **2.	Assess Situation**

# %% [markdown]
# Situasi Bisnis: Tingginya angka kecelakaan lalu lintas, baik yang bersifat minor maupun fatal, menunjukkan bahwa keselamatan di jalan masih menjadi permasalahan serius. Faktor penyebab kecelakaan melibatkan berbagai aspek, seperti kondisi cuaca, kepadatan lalu lintas, kualitas infrastruktur, dan perilaku pengemudi. Oleh karena itu, analisis faktor-faktor ini menjadi krusial bagi pemerintah dan pemangku kepentingan lainnya untuk merancang kebijakan yang lebih efektif dalam meningkatkan keamanan berkendara dan mengoptimalkan infrastruktur jalan.

# %% [markdown]
# ###**3.	Data Mining Goals**

# %% [markdown]
# Tujuan Data Mining: Tujuan dari data mining pada dataset ini adalah untuk memahami pola kecelakaan berdasarkan faktor-faktor seperti cuaca, batas kecepatan, kondisi jalan, dan kepadatan lalu lintas. Selain itu, hasil analisis ini dapat memberikan wawasan bagi pemerintah dan otoritas transportasi untuk menyusun kebijakan yang lebih efektif dalam meningkatkan keselamatan pengguna jalan.

# %% [markdown]
# ###**4.	Project Plan**

# %% [markdown]
# Project Plan: Proyek ini dilakukan melalui serangkaian tahapan penting dalam analisis data. Tahap pertama adalah pengumpulan data, diikuti dengan pembersihan data untuk memastikan kualitas data yang baik dengan menghapus nilai yang tidak valid, menangani data yang hilang, serta mengelola outliers. Selanjutnya, dilakukan analisis data melalui eksplorasi menggunakan tools seperti Excel atau Python guna mengidentifikasi pola serta hubungan antarvariabel dalam dataset. Berdasarkan hasil analisis, dibuat visualisasi data serta rekomendasi tindakan berbasis data yang dapat digunakan oleh pemerintah atau stakeholders dalam upaya peningkatan keselamatan lalu lintas.

# %% [markdown]
# # **Checkpoin 2**

# %% [markdown]
# link dataset: [Traffic Accident Prediction](https://www.kaggle.com/datasets/denkuznetz/traffic-accident-prediction/data://)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("//content/drive/MyDrive/pandas/dataset_accident_prediction.csv")

df
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0     Rainy   City Road     Morning              1.0        100.0
# 1     Clear  Rural Road       Night              NaN        120.0
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        195.0
# ..      ...         ...         ...              ...          ...
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              NaN         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                   5.0             0.0               NaN                 Wet
# ...

# %% [markdown]
# ## **Melihat Struktur Data**

# %%
# Memeriksa tipe data variabel pada dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Weather               798 non-null    object
#  1   Road_Type             798 non-null    object
#  2   Time_of_Day           798 non-null    object
#  3   Traffic_Density       798 non-null    float64
#  4   Speed_Limit           798 non-null    float64
#  5   Number_of_Vehicles    798 non-null    float64
#  6   Driver_Alcohol        798 non-null    float64
#  7   Accident_Severity     798 non-null    object
#  8   Road_Condition        798 non-null    object
#  9   Vehicle_Type          798 non-null    object
#  10  Driver_Age            798 non-null    float64
#  11  Driver_Experience     798 non-null    float64
#  12  Road_Light_Condition  798 non-null    object
#  13  Accident              798 non-null    float64
# dtypes: float64(7), object(7)
# ...

# %%
df.head(4)
# Out:
#   Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0   Rainy   City Road     Morning              1.0        100.0
# 1   Clear  Rural Road       Night              NaN        120.0
# 2   Rainy     Highway     Evening              1.0         60.0
# 3   Clear   City Road   Afternoon              2.0         60.0
#
#    Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                 5.0             0.0               NaN                 Wet
# 1                 3.0             0.0          Moderate                 Wet
# 2                 4.0             0.0               Low                 Icy
# 3                 3.0             0.0               Low  Under Construction
#
#   Vehicle_Type  Driver_Age  Driver_Experience Road_Light_Condition  Accident
# 0          Car        51.0               48.0     Artificial Light       0.0
# 1        Truck        49.0               43.0     Artificial Light       0.0
# ...

# %%
df.tail(4)
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              NaN         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity Road_Condition  \
# 836                 4.0             0.0               Low            Dry
# 837                 4.0             1.0              High            Dry
# 838                 3.0             0.0               Low            Dry
# 839                 4.0             0.0               Low            Dry
#
#     Vehicle_Type  Driver_Age  Driver_Experience Road_Light_Condition  Accident
# 836   Motorcycle        52.0               46.0             Daylight       1.0
# 837          Car         NaN               34.0     Artificial Light       NaN
# ...

# %%
# Mengetahui jumlah baris dan kolom dataset
print(f"Jumlah baris: {df.shape[0]}")
print(f"Jumlah kolom: {df.shape[1]}")
# Out:
# Jumlah baris: 840
# Jumlah kolom: 14

# %%
df.dtypes
# Out:
# Weather                  object
# Road_Type                object
# Time_of_Day              object
# Traffic_Density         float64
# Speed_Limit             float64
# Number_of_Vehicles      float64
# Driver_Alcohol          float64
# Accident_Severity        object
# Road_Condition           object
# Vehicle_Type             object
# Driver_Age              float64
# Driver_Experience       float64
# Road_Light_Condition     object
# Accident                float64
# dtype: object

# %% [markdown]
# ## **Statistik Deskriptif**

# %%
df.describe()
# Out:
#        Traffic_Density  Speed_Limit  Number_of_Vehicles  Driver_Alcohol  \
# count       798.000000   798.000000          798.000000      798.000000
# mean          1.001253    71.050125            3.286967        0.160401
# std           0.784894    32.052458            2.017267        0.367208
# min           0.000000    30.000000            1.000000        0.000000
# 25%           0.000000    50.000000            2.000000        0.000000
# 50%           1.000000    60.000000            3.000000        0.000000
# 75%           2.000000    80.000000            4.000000        0.000000
# max           2.000000   213.000000           14.000000        1.000000
#
#        Driver_Age  Driver_Experience    Accident
# count  798.000000         798.000000  798.000000
# mean    43.259398          38.981203    0.299499
# std     15.129856          15.273201    0.458326
# min     18.000000           9.000000    0.000000
# 25%     30.000000          26.000000    0.000000
# ...

# %% [markdown]
# kode diatas berguna untuk menampilkan ringkasan statistik yang menliputi mean, median, nilai minimum dan maksimum serta quartil dari suatu data.

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Clear     334
# Rainy     230
# Foggy     107
# Snowy      87
# Stormy     40
# Name: count, dtype: int64

# %%
df['Road_Type'].value_counts()
# Out:
# Road_Type
# Highway          402
# City Road        230
# Rural Road       125
# Mountain Road     41
# Name: count, dtype: int64

# %%
df['Time_of_Day'].value_counts()
# Out:
# Time_of_Day
# Afternoon    272
# Evening      218
# Morning      201
# Night        107
# Name: count, dtype: int64

# %%
df['Traffic_Density'].value_counts()
# Out:
# Traffic_Density
# 1.0    307
# 2.0    246
# 0.0    245
# Name: count, dtype: int64

# %%
df['Speed_Limit'].value_counts()
# Out:
# Speed_Limit
# 60.0     231
# 50.0     162
# 80.0     143
# 100.0    124
# 30.0      84
# 120.0     29
# 208.0      2
# 192.0      2
# 213.0      2
# 206.0      2
# 178.0      2
# 195.0      2
# 189.0      2
# 185.0      1
# 212.0      1
# 198.0      1
# 199.0      1
# 190.0      1
# 193.0      1
# 194.0      1
# 188.0      1
# 196.0      1
# 200.0      1
# 181.0      1
# Name: count, dtype: int64

# %%
df['Number_of_Vehicles'].value_counts()
# Out:
# Number_of_Vehicles
# 3.0     163
# 4.0     161
# 5.0     154
# 2.0     153
# 1.0     144
# 11.0      8
# 10.0      5
# 13.0      4
# 14.0      4
# 12.0      2
# Name: count, dtype: int64

# %%
df['Driver_Alcohol'].value_counts()
# Out:
# Driver_Alcohol
# 0.0    670
# 1.0    128
# Name: count, dtype: int64

# %%
df['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Low         478
# Moderate    241
# High         79
# Name: count, dtype: int64

# %%
df['Road_Condition'].value_counts()
# Out:
# Road_Condition
# Dry                   400
# Icy                   154
# Wet                   153
# Under Construction     91
# Name: count, dtype: int64

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car           589
# Truck          99
# Motorcycle     86
# Bus            24
# Name: count, dtype: int64

# %%
df['Driver_Age'].value_counts()
# Out:
# Driver_Age
# 46.0    27
# 27.0    24
# 33.0    23
# 24.0    22
# 68.0    21
# 52.0    21
# 43.0    21
# 48.0    21
# 69.0    20
# 34.0    20
# 36.0    19
# 65.0    19
# 67.0    19
# 59.0    18
# 23.0    18
# 58.0    17
# 40.0    17
# 41.0    17
# 54.0    17
# 30.0    16
# 42.0    16
# 21.0    16
# 19.0    16
# 29.0    16
# 32.0    16
# 53.0    15
# 18.0    15
# 60.0    14
# 35.0    14
# 64.0    14
# 50.0    14
# 62.0    13
# 56.0    13
# 25.0    13
# 20.0    13
# 26.0    13
# 22.0    13
# 28.0    12
# 38.0    12
# 39.0    12
# 49.0    12
# 61.0    12
# 47.0    11
# 45.0    11
# 44.0    11
# 37.0    10
# 51.0    10
# 66.0    10
# 57.0    10
# 55.0     9
# 63.0     8
# 31.0     7
# Name: count, dtype: int64

# %%
df['Driver_Experience'].value_counts()
# Out:
# Driver_Experience
# 41.0    26
# 40.0    22
# 53.0    21
# 27.0    21
# 54.0    20
# 31.0    20
# 55.0    20
# 61.0    19
# 25.0    19
# 39.0    19
# 26.0    19
# 18.0    19
# 24.0    19
# 17.0    18
# 43.0    17
# 62.0    17
# 37.0    17
# 34.0    17
# 60.0    17
# 22.0    17
# 57.0    17
# 19.0    16
# 52.0    16
# 33.0    15
# 51.0    15
# 35.0    15
# 30.0    14
# 38.0    14
# 45.0    14
# 23.0    14
# 36.0    14
# 50.0    13
# 44.0    13
# 48.0    13
# 42.0    12
# 46.0    12
# 14.0    11
# 63.0    11
# 15.0    11
# 21.0    11
# 49.0    10
# 59.0    10
# 13.0    10
# 32.0    10
# 29.0    10
# 58.0     9
# 20.0     9
# 56.0     9
# 64.0     9
# 47.0     9
# 28.0     9
# 65.0     8
# 67.0     7
# 10.0     5
# 66.0     5
# 12.0     5
# 16.0     4
# 11.0     2
# 9.0      2
# 69.0     1
# Name: count, dtype: int64

# %%
df['Road_Light_Condition'].value_counts()
# Out:
# Road_Light_Condition
# Artificial Light    402
# Daylight            320
# No Light             76
# Name: count, dtype: int64

# %%
df['Accident'].value_counts()
# Out:
# Accident
# 0.0    559
# 1.0    239
# Name: count, dtype: int64

# %% [markdown]
# kode diatas berguna untuk menghitung banyak kemunculan nilai unik pada suatu kolom. dengan begitu dapat mengetahui distribusi data dan nilai yang tidak konsisten.

# %%
# menghitung rata-rata setiap kolom
df.mean(numeric_only=True)
# Out:
# Traffic_Density        1.001253
# Speed_Limit           71.050125
# Number_of_Vehicles     3.286967
# Driver_Alcohol         0.160401
# Driver_Age            43.259398
# Driver_Experience     38.981203
# Accident               0.299499
# dtype: float64

# %%
# menghitung median setiap kolom
df.median(numeric_only=True)
# Out:
# Traffic_Density        1.0
# Speed_Limit           60.0
# Number_of_Vehicles     3.0
# Driver_Alcohol         0.0
# Driver_Age            43.0
# Driver_Experience     39.0
# Accident               0.0
# dtype: float64

# %%
#  menghitung standar deviasi setiap kolom
df.std(numeric_only=True)
# Out:
# Traffic_Density        0.784894
# Speed_Limit           32.052458
# Number_of_Vehicles     2.017267
# Driver_Alcohol         0.367208
# Driver_Age            15.129856
# Driver_Experience     15.273201
# Accident               0.458326
# dtype: float64

# %% [markdown]
# ketiga fungsi diatas digunakan untuk mengetahui mean, median dan standar deviasi setiap kolom yang terdapat dalam suatu dataset.

# %%
#  mengetahui korelasi antar kolom
df.corr(numeric_only=True)
# Out:
#                     Traffic_Density  Speed_Limit  Number_of_Vehicles  \
# Traffic_Density            1.000000    -0.045660           -0.040945
# Speed_Limit               -0.045660     1.000000            0.513254
# Number_of_Vehicles        -0.040945     0.513254            1.000000
# Driver_Alcohol            -0.020078    -0.014764           -0.022694
# Driver_Age                -0.010759     0.004224            0.022232
# Driver_Experience         -0.002428     0.001901            0.017878
# Accident                  -0.002455    -0.026197            0.040544
#
#                     Driver_Alcohol  Driver_Age  Driver_Experience  Accident
# Traffic_Density          -0.020078   -0.010759          -0.002428 -0.002455
# Speed_Limit              -0.014764    0.004224           0.001901 -0.026197
# Number_of_Vehicles       -0.022694    0.022232           0.017878  0.040544
# Driver_Alcohol            1.000000    0.024579           0.025362  0.022672
# ...

# %% [markdown]
# fungsi df.corr() digunakan untuk mengetahui korelasi, apakah positif atau negatif, antara kolom numerik yang terdapat dalam suatu dataset.

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Melihat missing values**

# %%
# mengecek persentase missing values
print((df.isna().sum() / len(df)) * 100)
# Out:
# Weather                 5.0
# Road_Type               5.0
# Time_of_Day             5.0
# Traffic_Density         5.0
# Speed_Limit             5.0
# Number_of_Vehicles      5.0
# Driver_Alcohol          5.0
# Accident_Severity       5.0
# Road_Condition          5.0
# Vehicle_Type            5.0
# Driver_Age              5.0
# Driver_Experience       5.0
# Road_Light_Condition    5.0
# Accident                5.0
# dtype: float64

# %% [markdown]
# kode diatas digunakan untuk mengetahui persentase missing values pada setiap kolom dalam suatu dataset.

# %%
df[df['Weather'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 12      NaN     Rural Road   Afternoon              0.0         60.0
# 27      NaN      City Road     Evening              0.0        100.0
# 31      NaN        Highway   Afternoon              1.0         30.0
# 70      NaN  Mountain Road     Evening              NaN        206.0
# 79      NaN        Highway       Night              1.0         30.0
# 80      NaN        Highway     Evening              0.0         30.0
# 123     NaN            NaN         NaN              1.0        208.0
# 128     NaN     Rural Road       Night              1.0         80.0
# 145     NaN        Highway     Evening              2.0         50.0
# 150     NaN        Highway     Morning              1.0         80.0
# 155     NaN        Highway   Afternoon              2.0          NaN
# 159     NaN  Mountain Road       Night              2.0         80.0
# 187     NaN        Highway     Morning              2.0         80.0
# ...

# %%
df[df['Road_Type'].isnull()]
# Out:
#     Weather Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 10    Foggy       NaN     Evening              NaN         60.0
# 17    Snowy       NaN   Afternoon              1.0        100.0
# 28   Stormy       NaN   Afternoon              2.0         80.0
# 40    Rainy       NaN       Night              1.0         50.0
# 43    Snowy       NaN     Evening              2.0         50.0
# 61    Rainy       NaN     Evening              1.0         50.0
# 112   Rainy       NaN     Morning              2.0         30.0
# 123     NaN       NaN         NaN              1.0        208.0
# 166   Clear       NaN     Morning              2.0         60.0
# 171   Clear       NaN     Morning              0.0         30.0
# 183   Clear       NaN     Morning              1.0        100.0
# 197   Clear       NaN   Afternoon              1.0         60.0
# 201   Clear       NaN     Morning              2.0        100.0
# 209   Snowy       NaN   Afternoon              0.0         80.0
# ...

# %%
df[df['Time_of_Day'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 16    Rainy      City Road         NaN              0.0         60.0
# 53    Clear        Highway         NaN              2.0         60.0
# 123     NaN            NaN         NaN              1.0        208.0
# 130   Clear      City Road         NaN              0.0         50.0
# 142   Snowy        Highway         NaN              NaN         60.0
# 149   Rainy        Highway         NaN              2.0         60.0
# 163   Clear        Highway         NaN              1.0         50.0
# 199   Clear      City Road         NaN              2.0         50.0
# 214   Clear      City Road         NaN              2.0         60.0
# 243   Rainy      City Road         NaN              2.0        100.0
# 262   Rainy        Highway         NaN              0.0         60.0
# 281   Clear        Highway         NaN              1.0         50.0
# 287   Clear        Highway         NaN              2.0         60.0
# ...

# %%
df[df['Traffic_Density'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 1     Clear     Rural Road       Night              NaN        120.0
# 10    Foggy            NaN     Evening              NaN         60.0
# 70      NaN  Mountain Road     Evening              NaN        206.0
# 142   Snowy        Highway         NaN              NaN         60.0
# 153   Rainy        Highway     Morning              NaN         30.0
# 161   Rainy        Highway     Evening              NaN        100.0
# 168   Foggy        Highway     Morning              NaN         80.0
# 174   Rainy        Highway       Night              NaN        120.0
# 177   Clear     Rural Road   Afternoon              NaN         80.0
# 184   Clear      City Road   Afternoon              NaN         50.0
# 195   Clear      City Road   Afternoon              NaN         60.0
# 207   Foggy      City Road     Morning              NaN         60.0
# 223   Rainy      City Road     Morning              NaN         30.0
# ...

# %%
df[df['Speed_Limit'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 14    Clear     Rural Road     Morning              0.0          NaN
# 35   Stormy        Highway     Morning              1.0          NaN
# 39    Clear      City Road       Night              0.0          NaN
# 60    Clear        Highway     Morning              0.0          NaN
# 69    Clear        Highway     Evening              2.0          NaN
# 91    Clear        Highway     Evening              0.0          NaN
# 155     NaN        Highway   Afternoon              2.0          NaN
# 202   Clear        Highway     Evening              1.0          NaN
# 204     NaN        Highway     Evening              2.0          NaN
# 212     NaN      City Road     Morning              0.0          NaN
# 217   Rainy        Highway   Afternoon              1.0          NaN
# 245   Rainy  Mountain Road   Afternoon              1.0          NaN
# 263   Rainy      City Road     Evening              1.0          NaN
# ...

# %%
df[df['Number_of_Vehicles'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 29    Clear      City Road   Afternoon              1.0         80.0
# 79      NaN        Highway       Night              1.0         30.0
# 135   Foggy        Highway     Evening              1.0        100.0
# 177   Clear     Rural Road   Afternoon              NaN         80.0
# 194   Clear      City Road   Afternoon              2.0        100.0
# 208   Rainy        Highway     Morning              0.0         60.0
# 221   Clear     Rural Road     Evening              2.0         80.0
# 235   Rainy      City Road     Evening              1.0         60.0
# 236   Rainy     Rural Road     Evening              1.0         50.0
# 244   Clear     Rural Road     Morning              1.0        194.0
# 251   Clear            NaN     Morning              0.0         60.0
# 324   Foggy      City Road   Afternoon              1.0        120.0
# 330   Clear        Highway   Afternoon              2.0         60.0
# ...

# %%
df[df['Driver_Alcohol'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 35   Stormy        Highway     Morning              1.0          NaN
# 57    Rainy  Mountain Road     Evening              0.0         50.0
# 62    Rainy      City Road   Afternoon              1.0        200.0
# 63    Clear        Highway     Evening              2.0        120.0
# 72    Rainy        Highway   Afternoon              0.0        120.0
# 81    Clear        Highway   Afternoon              2.0         80.0
# 118   Clear     Rural Road     Morning              2.0         60.0
# 119   Rainy     Rural Road     Morning              1.0         60.0
# 139   Rainy      City Road       Night              2.0         50.0
# 140   Clear      City Road       Night              1.0         60.0
# 168   Foggy        Highway     Morning              NaN         80.0
# 187     NaN        Highway     Morning              2.0         80.0
# 192   Snowy        Highway     Morning              0.0         30.0
# ...

# %%
df[df['Accident_Severity'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0     Rainy      City Road     Morning              1.0        100.0
# 12      NaN     Rural Road   Afternoon              0.0         60.0
# 17    Snowy            NaN   Afternoon              1.0        100.0
# 100   Foggy      City Road     Morning              1.0         30.0
# 120   Foggy      City Road   Afternoon              1.0         80.0
# 142   Snowy        Highway         NaN              NaN         60.0
# 144   Clear     Rural Road     Evening              2.0         80.0
# 152   Snowy     Rural Road     Evening              0.0         80.0
# 163   Clear        Highway         NaN              1.0         50.0
# 186   Rainy      City Road     Evening              2.0        120.0
# 188   Snowy        Highway       Night              0.0         50.0
# 246   Rainy     Rural Road   Afternoon              2.0         80.0
# 252   Snowy  Mountain Road       Night              0.0         50.0
# ...

# %%
df[df['Road_Condition'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 5     Clear     Rural Road       Night              0.0        120.0
# 13    Rainy      City Road       Night              0.0         30.0
# 14    Clear     Rural Road     Morning              0.0          NaN
# 24    Rainy        Highway     Morning              1.0         50.0
# 76    Clear        Highway   Afternoon              1.0         50.0
# 84    Rainy      City Road   Afternoon              0.0         80.0
# 149   Rainy        Highway         NaN              2.0         60.0
# 154   Clear        Highway     Evening              2.0         80.0
# 159     NaN  Mountain Road       Night              2.0         80.0
# 161   Rainy        Highway     Evening              NaN        100.0
# 227   Snowy      City Road   Afternoon              1.0         50.0
# 245   Rainy  Mountain Road   Afternoon              1.0          NaN
# 252   Snowy  Mountain Road       Night              0.0         50.0
# ...

# %%
df[df['Vehicle_Type'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 23    Rainy     Rural Road   Afternoon              0.0         30.0
# 29    Clear      City Road   Afternoon              1.0         80.0
# 90    Clear      City Road   Afternoon              2.0         60.0
# 95    Clear  Mountain Road   Afternoon              1.0        100.0
# 101   Clear      City Road     Evening              1.0         80.0
# 105   Foggy        Highway     Morning              1.0        100.0
# 154   Clear        Highway     Evening              2.0         80.0
# 156   Clear        Highway     Evening              1.0        100.0
# 178   Foggy        Highway     Evening              0.0         60.0
# 190   Clear        Highway     Evening              0.0         60.0
# 208   Rainy        Highway     Morning              0.0         60.0
# 218   Clear        Highway     Morning              0.0        100.0
# 268  Stormy        Highway     Morning              1.0         50.0
# ...

# %%
df[df['Driver_Age'].isnull()]
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 30    Rainy     Highway     Morning              1.0         80.0
# 49    Clear     Highway     Evening              0.0         50.0
# 50    Rainy   City Road     Morning              0.0         60.0
# 72    Rainy     Highway   Afternoon              0.0        120.0
# 108   Rainy     Highway     Evening              2.0         60.0
# 118   Clear  Rural Road     Morning              2.0         60.0
# 121   Rainy     Highway     Evening              0.0         60.0
# 160   Foggy   City Road     Morning              1.0         50.0
# 169   Foggy     Highway   Afternoon              1.0         80.0
# 179   Clear     Highway   Afternoon              0.0        100.0
# 255   Clear     Highway     Evening              2.0         80.0
# 339   Rainy   City Road     Evening              1.0        100.0
# 340   Rainy     Highway         NaN              2.0         80.0
# ...

# %%
df[df['Driver_Experience'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 15    Clear     Rural Road       Night              0.0         60.0
# 17    Snowy            NaN   Afternoon              1.0        100.0
# 37    Rainy        Highway     Evening              0.0        120.0
# 38    Clear        Highway     Morning              2.0        100.0
# 47    Clear        Highway       Night              1.0         30.0
# 49    Clear        Highway     Evening              0.0         50.0
# 84    Rainy      City Road   Afternoon              0.0         80.0
# 107   Rainy        Highway     Morning              1.0         60.0
# 117   Rainy  Mountain Road   Afternoon              1.0         60.0
# 120   Foggy      City Road   Afternoon              1.0         80.0
# 135   Foggy        Highway     Evening              1.0        100.0
# 149   Rainy        Highway         NaN              2.0         60.0
# 159     NaN  Mountain Road       Night              2.0         80.0
# ...

# %%
df[df['Road_Light_Condition'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 21    Foggy     Rural Road     Evening              0.0        100.0
# 36    Clear      City Road     Evening              2.0         50.0
# 54    Snowy      City Road     Morning              2.0         80.0
# 55    Rainy      City Road   Afternoon              2.0        100.0
# 70      NaN  Mountain Road     Evening              NaN        206.0
# 73    Clear      City Road     Evening              1.0         80.0
# 132   Clear        Highway     Evening              0.0        120.0
# 137   Clear        Highway   Afternoon              2.0         60.0
# 173   Rainy        Highway       Night              0.0        120.0
# 182   Rainy        Highway   Afternoon              0.0         80.0
# 205   Rainy        Highway     Evening              2.0         60.0
# 219  Stormy     Rural Road     Evening              1.0         80.0
# 255   Clear        Highway     Evening              2.0         80.0
# ...

# %%
df[df['Accident'].isnull()]
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 10    Foggy            NaN     Evening              NaN         60.0
# 57    Rainy  Mountain Road     Evening              0.0         50.0
# 105   Foggy        Highway     Morning              1.0        100.0
# 109   Clear      City Road     Morning              1.0        120.0
# 114   Foggy      City Road     Morning              0.0        100.0
# 136   Rainy     Rural Road   Afternoon              2.0         60.0
# 160   Foggy      City Road     Morning              1.0         50.0
# 226     NaN        Highway       Night              1.0         60.0
# 274   Clear        Highway   Afternoon              0.0         60.0
# 276   Snowy     Rural Road     Morning              1.0         50.0
# 288   Rainy        Highway         NaN              1.0        100.0
# 307  Stormy     Rural Road         NaN              1.0         60.0
# 310   Foggy        Highway     Evening              1.0        100.0
# ...

# %% [markdown]
# dilakukan pengecekkan nilai kosong pada setiap kolom yang berada dalam dataset. hal ini dilakukan untuk mengetahui baris apa saja yang memiliki nilai kosong.

# %% [markdown]
# ### **Mengatasi Missing Values**

# %% [markdown]
# setiap kolom pada dataset ini memiliki mising value sebesar 5% atau <=70% sehingga perlu dilakukan imputasi dengan mengganti data yang kosong menggunakan mean/median/modus dari kolom terkait.

# %% [markdown]
# **Melakukan Imputasi**

# %%
df['Weather'].dropna().describe()
# Out:
# count       798
# unique        5
# top       Clear
# freq        334
# Name: Weather, dtype: object

# %%
df['Weather'] = df['Weather'].fillna(df['Weather'].mode()[0])

# %%
df['Road_Type'].dropna().describe()
# Out:
# count         798
# unique          4
# top       Highway
# freq          402
# Name: Road_Type, dtype: object

# %%
df['Road_Type'] = df['Road_Type'].fillna(df['Road_Type'].mode()[0])

# %%
df['Time_of_Day'].dropna().describe()
# Out:
# count           798
# unique            4
# top       Afternoon
# freq            272
# Name: Time_of_Day, dtype: object

# %%
df['Time_of_Day'] = df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0])

# %%
df['Accident_Severity'].dropna().describe()
# Out:
# count     798
# unique      3
# top       Low
# freq      478
# Name: Accident_Severity, dtype: object

# %%
df['Accident_Severity'] = df['Accident_Severity'].fillna(df['Accident_Severity'].mode()[0])

# %%
df['Road_Condition'].dropna().describe()
# Out:
# count     798
# unique      4
# top       Dry
# freq      400
# Name: Road_Condition, dtype: object

# %%
df['Road_Condition'] = df['Road_Condition'].fillna(df['Road_Condition'].mode()[0])

# %%
df['Vehicle_Type'].dropna().describe()
# Out:
# count     798
# unique      4
# top       Car
# freq      589
# Name: Vehicle_Type, dtype: object

# %%
df['Vehicle_Type'] = df['Vehicle_Type'].fillna(df['Vehicle_Type'].mode()[0])

# %%
df['Road_Light_Condition'].dropna().describe()
# Out:
# count                  798
# unique                   3
# top       Artificial Light
# freq                   402
# Name: Road_Light_Condition, dtype: object

# %%
df['Road_Light_Condition'] = df['Road_Light_Condition'].fillna(df['Road_Light_Condition'].mode()[0])

# %% [markdown]
# ke-6 kolom diatas memiliki tipe data string sehingga imputasi dilakukan dengan mengganti data yang hilang dengan modus dari kolom terkait.

# %%
df['Traffic_Density'].dropna().describe()
# Out:
# count    798.000000
# mean       1.001253
# std        0.784894
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000
# Name: Traffic_Density, dtype: float64

# %%
traffic_density_mode = df['Traffic_Density'].mode()[0]
print(f"Modus dari kolom driver_alcohol: {traffic_density_mode}")

df['Traffic_Density'] = df['Traffic_Density'].fillna(df['Traffic_Density'].mode()[0])
# Out:
# Modus dari kolom driver_alcohol: 1.0

# %%
df['Driver_Alcohol'].dropna().describe()
# Out:
# count    798.000000
# mean       0.160401
# std        0.367208
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: Driver_Alcohol, dtype: float64

# %%
driver_alcohol_mode = df['Driver_Alcohol'].mode()[0]
print(f"Modus dari kolom driver_alcohol: {driver_alcohol_mode}")

df['Driver_Alcohol'] = df['Driver_Alcohol'].fillna(df['Driver_Alcohol'].mode()[0])
# Out:
# Modus dari kolom driver_alcohol: 0.0

# %% [markdown]
# variabel Traffic_Density dan Driver_Alcohol merupakan data kategorikal sehingga imputasi dilakukan dengan mengganti missing values dengan modus dari kolom terkait.

# %%
df['Speed_Limit'].dropna().describe()
# Out:
# count    798.000000
# mean      71.050125
# std       32.052458
# min       30.000000
# 25%       50.000000
# 50%       60.000000
# 75%       80.000000
# max      213.000000
# Name: Speed_Limit, dtype: float64

# %%
df['Speed_Limit'] = df['Speed_Limit'].fillna(df['Speed_Limit'].dropna().mean())

# %%
df['Number_of_Vehicles'].dropna().describe()
# Out:
# count    798.000000
# mean       3.286967
# std        2.017267
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max       14.000000
# Name: Number_of_Vehicles, dtype: float64

# %%
df['Number_of_Vehicles'] = df['Number_of_Vehicles'].fillna(df['Number_of_Vehicles'].dropna().mean())

# %%
df['Driver_Age'].dropna().describe()
# Out:
# count    798.000000
# mean      43.259398
# std       15.129856
# min       18.000000
# 25%       30.000000
# 50%       43.000000
# 75%       56.000000
# max       69.000000
# Name: Driver_Age, dtype: float64

# %%
df['Driver_Age'] = df['Driver_Age'].fillna(df['Driver_Age'].dropna().mean())

# %%
df['Driver_Experience'].dropna().describe()
# Out:
# count    798.000000
# mean      38.981203
# std       15.273201
# min        9.000000
# 25%       26.000000
# 50%       39.000000
# 75%       52.750000
# max       69.000000
# Name: Driver_Experience, dtype: float64

# %%
df['Driver_Experience'] = df['Driver_Experience'].fillna(df['Driver_Experience'].dropna().mean())

# %%
df['Accident'].dropna().describe()
# Out:
# count    798.000000
# mean       0.299499
# std        0.458326
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Accident, dtype: float64

# %%
df['Accident'] = df['Accident'].fillna(df['Accident'].dropna().mean())

# %% [markdown]
# variabel yang memiliki tipe data numerik sehingga nilai kosong akan diimputasi dengan mean kolom terkait.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                       Null Ratio %
# Weather                        0.0
# Road_Type                      0.0
# Time_of_Day                    0.0
# Traffic_Density                0.0
# Speed_Limit                    0.0
# Number_of_Vehicles             0.0
# Driver_Alcohol                 0.0
# Accident_Severity              0.0
# Road_Condition                 0.0
# Vehicle_Type                   0.0
# Driver_Age                     0.0
# Driver_Experience              0.0
# Road_Light_Condition           0.0
# Accident                       0.0

# %% [markdown]
# setelah dilakukan imputasi, terlihat bahwa persentase missing value pada setiap kolom menjadi 0, yang artinya data sudah tidak memiliki nilai kosong lagi.

# %% [markdown]
# ### **Duplicated Values**

# %%
# mengecek data yang terduplikasi
df[df.duplicated()]
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 261   Rainy     Highway   Afternoon              0.0         60.0
# 270   Snowy     Highway     Morning              2.0         60.0
# 292   Clear     Highway     Morning              1.0         60.0
# 410   Clear   City Road     Morning              2.0         50.0
# 431   Clear     Highway     Morning              2.0        100.0
# 440   Clear   City Road     Morning              2.0         50.0
# 446   Clear     Highway   Afternoon              0.0         60.0
# 487   Rainy   City Road   Afternoon              0.0         60.0
# 528   Rainy     Highway     Evening              1.0         60.0
# 560   Rainy     Highway   Afternoon              0.0         60.0
# 614   Clear     Highway   Afternoon              1.0         30.0
# 629   Clear  Rural Road     Evening              0.0         60.0
# 671   Clear  Rural Road     Evening              2.0         80.0
# ...

# %%
#  menghapus duplikasi
df = df.drop_duplicates()

# data setelah duplikasi dihapus
df
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0     Rainy   City Road     Morning              1.0        100.0
# 1     Clear  Rural Road       Night              1.0        120.0
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        195.0
# ..      ...         ...         ...              ...          ...
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              1.0         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                   5.0             0.0               Low                 Wet
# ...

# %% [markdown]
# data yang terduplikasi atau muncul beberapa kali dalam suatu dataset perlu segera ditangani dengan cara menghapus duplikasi tersebut.

# %% [markdown]
# ## **Outliers**

# %%
# mengecek keberadaan outliers
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# Traffic_Density                0.000000
# Speed_Limit                    3.037667
# Number_of_Vehicles             2.794654
# Driver_Alcohol                15.552855
# Driver_Age                     0.000000
# Driver_Experience              0.000000
# Accident                       0.000000

# %% [markdown]
# berdasarkan hasil perhitungan, diketahui terdapat outliers pada kolom speed limit, number of vehicles, dan driver alcohol. namun, persentase outliers pada driver alcohol >= 10%, sehingga imputasi hanya dilakukan terhadap speed limit dan number of vehicles.

# %%
columns_to_impute = ["Speed_Limit", "Number_of_Vehicles"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
# mengecek outliers setelah dilakukan imputasi
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# Traffic_Density                0.000000
# Speed_Limit                    0.000000
# Number_of_Vehicles             0.000000
# Driver_Alcohol                15.552855
# Driver_Age                     0.000000
# Driver_Experience              0.000000
# Accident                       0.000000

# %%
df
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0     Rainy   City Road     Morning              1.0        100.0
# 1     Clear  Rural Road       Night              1.0        120.0
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        125.0
# ..      ...         ...         ...              ...          ...
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              1.0         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                   5.0             0.0               Low                 Wet
# ...

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# Dataset ini tidak memiliki inconsistent values.

# %% [markdown]
# ### **Construct Data**

# %%
df["Indeks_Risiko_Pengemudi"] = (df["Driver_Age"] / df["Driver_Experience"]).round(1)
print(df.head())
# Out:
#   Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0   Rainy   City Road     Morning              1.0        100.0
# 1   Clear  Rural Road       Night              1.0        120.0
# 2   Rainy     Highway     Evening              1.0         60.0
# 3   Clear   City Road   Afternoon              2.0         60.0
# 4   Rainy     Highway     Morning              1.0        125.0
#
#    Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                 5.0             0.0               Low                 Wet
# 1                 3.0             0.0          Moderate                 Wet
# 2                 4.0             0.0               Low                 Icy
# 3                 3.0             0.0               Low  Under Construction
# 4                 7.0             0.0               Low                 Dry
#
#   Vehicle_Type  Driver_Age  Driver_Experience Road_Light_Condition  Accident  \
# ...

# %% [markdown]
# sesuai dengan tujuan analisis, saya menambahkan kolom indeks risiko yang dapat membantu memahami bagaimana usia dan pengalaman pengemudi dapat berkontribusi terhadap penyebab kecelakaan lalu lintas.

# %%
df.tail()
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              1.0         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity Road_Condition  \
# 835                 4.0             0.0               Low            Dry
# 836                 4.0             0.0               Low            Dry
# 837                 4.0             1.0              High            Dry
# 838                 3.0             0.0               Low            Dry
# 839                 4.0             0.0               Low            Dry
#
#     Vehicle_Type  Driver_Age  Driver_Experience Road_Light_Condition  \
# ...

# %%
df = df.drop('Road_Light_Condition', axis=1)

# %%
df = df.drop('Road_Type', axis=1)

# %%
df = df.drop('Driver_Age', axis=1)

# %%
df = df.drop('Driver_Experience', axis=1)

# %%
df.head(10)
# Out:
#   Weather Time_of_Day  Traffic_Density  Speed_Limit  Number_of_Vehicles  \
# 0   Rainy     Morning              1.0        100.0                 5.0
# 1   Clear       Night              1.0        120.0                 3.0
# 2   Rainy     Evening              1.0         60.0                 4.0
# 3   Clear   Afternoon              2.0         60.0                 3.0
# 4   Rainy     Morning              1.0        125.0                 7.0
# 5   Clear       Night              0.0        120.0                 3.0
# 6   Foggy   Afternoon              0.0         60.0                 4.0
# 7   Rainy   Afternoon              0.0         60.0                 4.0
# 8  Stormy     Morning              1.0         60.0                 2.0
# 9   Rainy   Afternoon              2.0         30.0                 2.0
#
#    Driver_Alcohol Accident_Severity      Road_Condition Vehicle_Type  \
# 0             0.0               Low                 Wet          Car
# ...

# %% [markdown]
# variabel Road Light Condition, Road Type, Driver Age, Driver Experience dihapus karena dianggap kurang relevan terhadap tujuan analisis ini dan sudah ada variabel lain yang mewakili variabel tersebut.
